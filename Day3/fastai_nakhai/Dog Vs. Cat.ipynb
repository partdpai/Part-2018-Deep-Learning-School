# %% [markdown]
# #  <div style="direction:rtl ;font-family: B Nazanin ;font-size:77px; line-height: 170%; text-align: center"> به نام خدا</div>

# %% [markdown]
# https://github.com/fastai/fastai

# %% [markdown]
# http://course.fast.ai/
#
# https://medium.com/@hiromi_suenaga

# %% [markdown]
# #  <div style="direction:rtl ;font-family: B Nazanin ;font-size:34px; line-height: 170%; text-align: center"> مقایسه کتابخانه fastai با سایر کتابخانه های یادگیری عمیق  </div>

# %% [markdown]
# #  <div style="direction:rtl ;font-family: B Nazanin ;font-size:23px; line-height: 170%; text-align: right"> معایب  </div>
#  <div style="direction:rtl ;font-family: B Nazanin ;font-size:18px; line-height: 170%; text-align: right">
#   <li>
#   	مستندسازی ضعیفی دارد.
#  </li>
#    <li>
# وابسته به pytoch است که خود این کتابخانه قابلیت های بالا و دارای بلوغی برای به کار گیری در موارد واقعی مثل سرورها، تلفن های همراه و .... در مقابل کتابخانه هایی مثل تنسورفلو را ندارد.
# </li>
#    <li>
# به علاوه پایتورچ قابلیت اجرا بر روی بسیاری از دستگاه ها و پردازشگرها مثل TPU های گوگل را ندارد.
# </li>
#     <li>
# هنوز به اندازه کافی توسط کاربران و شرکت های بزرگ استفاده نمی شود.
# </li>
#      <li>
# هنوز به اندازه کافی توسط کاربران و شرکت های بزرگ استفاده نمی شود.
# </li>
#     <li>
# هنوز در برخی از جاها fastai دارای نواقصی است. به طور مثال یک API آن که بر روی مسائل دسته بندی کار می کند ممکن است برای مسائل رگرسیون کار نکند.
# </li>

# %% [markdown]
# #  <div style="direction:rtl ;font-family: B Nazanin ;font-size:23px; line-height: 170%; text-align: right"> مزایا  </div>
#  <div style="direction:rtl ;font-family: B Nazanin ;font-size:18px; line-height: 170%; text-align: right">
#      <li>
# 	بسیاری از رویه های برتر یادگیری عمیق و یادگیری ماشین در این کتابخانه پیاده سازی شده اند و برای همین آموزش آن سریع تر است و صحت بالاتری را نیز به ما می دهد.
# </li>
#
# <li>
# کار با آن برای داده های جدولی راحت تر و بهتر است.
# </li>
#
# <li>
# با اکوسیستم پایتون مثل پانداس راحت تر یکپارچه می شود
# </li>
#
# <li>
# 	ذات پویا بود فریمورک پایتورچ باعث میشود که بتوان راحت تر با آن آزمایش و تکرار کرد و برای همین است که بسیاری از مقالات با پایتورچ پیاده سازی شده اند.
#     </li>
#
#
#
#   </div>

# %% [markdown]
# #  <div style="direction:rtl ;font-family: B Nazanin ;font-size:34px; line-height: 170%; text-align: center"> نصب کتابخانه fastai  </div>

# %% [markdown]
# https://virgool.io/@partdpai/fastai-library-n5jokluamd3x

# %% [markdown]
# #  <div style="direction:rtl ;font-family: B Nazanin ;font-size:34px; line-height: 170%; text-align: center">اجرای کدها و GPU رایگان  </div>

# %% [markdown]
# snark.ai

# %% [markdown]
# google colab

# %% [markdown]
# <div style="direction:rtl ;font-family: B Nazanin ;font-size:23px; line-height: 170%; text-align: right"> در این جا از هم ما از مسئله دسته بندی تصاویر دیتاست سگ و گربه شروع می کنیم. یک ویژگی کتابخانه fastai این است که با استفاده از تکنیک های مدرنی که در آن پیاده سازی شده است به راحتی می توانیم یک مدل یادگیری را با هدف به دست آوردن صحت بسیار بالا آموزش دهیم.به طور مثال بعد از این یک شبکه عصبی را با استفاده از تصاویر سگ و گربه آموزش دادیم مدل ما قادر خواهد بود که بر اساس تصویر جدیدی که به آن می دهیم با صحت بالایی پیش بینی کند که آن تصویر متعلق به چه یک گربه است یا یک سگ.  </div>

# %% [markdown]
# <div style="direction:rtl ;font-family: B Nazanin ;font-size:23px; line-height: 170%; text-align: right">دیتاست سگ وگربه دارای 25000 تصویر برچسب گذاری شده از سگ ها و گربه ها در مجموعه آموزش و 12500 تصویر بدون برچسب در مجموعه تست است که می خواهیم برچسب های آن ها را پیشبینی کنیم.  </div>

# %% [markdown]
# http://files.fast.ai/data/

# %%
# !pip install pdl
from pdl import pdl
pdl.dogscats(verbose = True)

# %% [markdown]
# #  <div style="direction:rtl ;font-family: B Nazanin ;font-size:34px; line-height: 170%; text-align: center"> بررسی ساختار دیتاست  </div>
#
# <div style="direction:rtl ;font-family: B Nazanin ;font-size:22حط; line-height: 170%; text-align: center">
#      <li> مجموعه آموزش: دیتاستی است که از آن برای آموزش مدل یادگیری عمیق (ماشین) استفاده می کنیم
# </li>
#
# <li>
#
#      مجموعه اعتبارسنجی: دیتاستی که برای ارزیابی مدل یادگیری عمیق ما استفاده می شود.
#
# </li>
#
# <li>
# مجموعه تست : دیتاستی که *صرفا* می خواهیم بر روی آن پیشبینی انجام دهیم (برچسب ندارد)
# </li>
# </div>
#
#  ![title](images/folder.PNG)

# %% [markdown]
# #  <div style="direction:rtl ;font-family: B Nazanin ;font-size:34px; line-height: 170%; text-align: center"> آموزش اولین مدل یادگیری عمیق  </div>
#
# <div style="direction:rtl ;font-family: B Nazanin ;font-size:22px; line-height: 170%; text-align: center">
# <ol>
# برای آموزش یک مدل یادگیری عمیق باید گام های زیر را طی بکنیم:
#
#    <li> مسیر حاوی دیتاست را مشخص کنیم.
#
#
# </li>
#
#    <li>
# اندازه تصاویر مورد نیاز برای مدل را تعیین کنیم.
#
# </li>
#
#  <li>
# معماری مدل یادگیری عمیق و تبدیل های مورد نیاز به آن را مشخص کنیم
#
# </li>
#      <li>
# داده ها  را به صورت دسته به دسته بخوانیم
# </li>
#
#  <li>
#  یک مدل بسازیم و به آن داده ها را بدهیم
#
# </li>
#
#   <li>
# مدل را برازش کنیم (آموزش دهیم)
# </li>
#
# </ol>
# </div>
#
#
#
# <div style="direction:rtl ;font-family: B Nazanin ;font-size:23px; line-height: 170%; text-align: right">
# کتابخانه ها و ماژول هایی که مورد نیاز ما هستند همگی توسط fastai به برنامه اضافه می شوند.
#
# </div>

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.imports import *
from fastai.transforms import *
from fastai.model import *
from fastai.dataset import *
from fastai.conv_learner import *
from fastai.sgdr import * 
from fastai.plots import *

# %%
# !ls /media/hamim/9ff9f0c5-df5c-47d7-94bb-b1b7451e18fd/datanakhaee
# Out:
# data				    MirasText (1).zip	training
# dicom_dir.zip			    models		training.zip
# dogscats			    planet-competition	train-jpg (2)
# flowers				    Rossman.ipynb	train-jpg.tar
# flowers.zip			    test-jpg.tar.7z	train-jpg.tar.7z
# ID_0004_AGE_0056_CONTRAST_1_CT.dcm  Titanic.ipynb
# MirasText (1)			    tmp

# %% [markdown]
# <div style="direction:rtl ;font-family: B Nazanin ;font-size:23px; line-height: 170%; text-align: right">
#
# مسیر داده ها را مشخص می کنیم.  </div>

# %%
PATH = 'data/dogscats/'

# %%
os.listdir(PATH)
# Out:
# ['test1', 'valid', 'tmp', 'models', 'sample', 'train']

# %%
os.listdir(f'{PATH}train')
# Out:
# ['cats', 'dogs']

# %%
files = os.listdir(f'{PATH}train/dogs')[0:5]
files
# Out:
# ['dog.12272.jpg',
#  'dog.473.jpg',
#  'dog.5098.jpg',
#  'dog.1396.jpg',
#  'dog.8074.jpg']

# %%
img =plt.imread(f'{PATH}train/dogs/{files[0]}')
plt.imshow(img)

# %%
files = os.listdir(f'{PATH}train/cats')[0:5]
files
# Out:
# ['cat.12083.jpg',
#  'cat.7671.jpg',
#  'cat.11391.jpg',
#  'cat.3169.jpg',
#  'cat.158.jpg']

# %%
img =plt.imread(f'{PATH}train/cats/{files[2]}')
plt.imshow(img)

# %%
img[:1,:1]
# Out:
# array([[[91, 63, 52]]], dtype=uint8)

# %%
img.shape
# Out:
# (315, 284, 3)

# %% [markdown]
# <div style="direction:rtl ;font-family: B Nazanin ;font-size:23px; line-height: 170%; text-align: right">  ابعادی که می خواهیم تصاویر به آن تغییر اندازه پیدا کنند را مشخص می کنیم. تصاویر در مدل های resnet به صورت پیشفرض دارای اندازه ای برابر با 224 هستند و برای همین در ابتدا از این اندازه برای تصاویر استفاده کنیم   </div>

# %%
size = 224

# %% [markdown]
# <div style="direction:rtl ;font-family: B Nazanin ;font-size:23px; line-height: 170%; text-align: right">
# برای شروع ابتدا معماری مدل یادگیری عمیقی که می خواهیم برای آموزش داده ها از آن استفاده شود را مشخص می کنیم.   </div>

# %% [markdown]
# <div style="direction:rtl ;font-family: B Nazanin ;font-size:23px; line-height: 170%; text-align: right">که قبل از این که از یک معماری استفاده کنیم بر روی تصاویر ورودی به آن تبدیل هایی که برای کار کردن آن شبکه لازم هستند را اعمال کنیم.   </div>

# %%
arch = resnet34
tfms = tfms_from_model(arch,size)

# %% [markdown]
# https://medium.com/@pierre_guillou/understand-how-works-resnet-without-talking-about-residual-64698f157e0c
#
#  ![title](images/resnet34.jpeg)

# %% [markdown]
# <div style="direction:rtl ;font-family: B Nazanin ;font-size:23px; line-height: 170%; text-align: right">
#
# یک منبع خوب برای یاد گرفتن معماری های مختلف شبکه های کانولوشنال فیلم های ارائه مهندس حسن پور در دوره قبلی یادگیری عمیق پارت و سایت deeplearning.ir  است.
#
# </div>

# %% [markdown]
# https://www.aparat.com/v/LSj3T

# %% [markdown]
# https://www.aparat.com/v/0EHoK

# %% [markdown]
# <div style="direction:rtl ;font-family: B Nazanin ;font-size:23px; line-height: 170%; text-align: right">پس از تعیین تبدیل ها گام بعدی این است که متغیر به نام data بسازیم تا داده های مورد نیاز برای آموزش ، اعتبارسنجی و تست را برای ما آماده کند.    </div>

# %%
data = ImageClassifierData.from_paths(PATH,tfms=tfms)

# %%
x,y = next(iter(data.trn_dl))

# %%
x.shape
# Out:
# torch.Size([64, 3, 224, 224])

# %%
y.shape
# Out:
# torch.Size([64])

# %%
data.bs
# Out:
# 64

# %%
data.classes
# Out:
# ['cats', 'dogs']

# %%
data.val_y
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %% [markdown]
# # <div style="direction:rtl ;font-family: B Nazanin ;font-size:27px; line-height: 170%; text-align: right">تفاوت Epoch و Batch
#
#
#
#
# </div>
#
#
# <div style="direction:rtl ;font-family: B Nazanin ;font-size:23px; line-height: 170%; text-align: right">
#
# هر Epoch یعنی یک بار همه مشاهدات را یک بار برای آموزش مدل مورد استفاده قرار دهیم.
# در هر Epoch بخشی از مشاهدات را به صورت خرد خرد و به شکل Batch به مدل یادگیری می دهیم.
# </div>

# %% [markdown]
# <div style="direction:rtl ;font-family: B Nazanin ;font-size:23px; line-height: 170%; text-align: right">
# پس از ساخت شی داده حاوی دیتاست مان، با استفاده از ConvLearner.pretrained() یک شی learner می سازیم که شبکه عصبی ما را با ورودی معماری انتخاب شده و شی داده آموزش می دهد.   </div>

# %%
learn = ConvLearner.pretrained(arch,data)
learn.fit(0.01,3)
# Out:
# ...
# epoch      trn_loss   val_loss   accuracy
#     0      0.042998   0.029677   0.987399
#     1      0.045025   0.030007   0.989415
#     2      0.03505    0.025647   0.989919
# [array([0.02565]), 0.9899193548387096]

# %% [markdown]
# # <div style="direction:rtl ;font-family: B Nazanin ;font-size:27px; line-height: 170%; text-align: right">پیشبینی</div>

# %%
log_preds = learn.predict()
log_preds.shape
# Out:
# (1984, 2)

# %% [markdown]
# ![title](images/softmax.PNG)

# %%
log_preds[:5]
# Out:
# array([[ -0.00001, -11.19711],
#        [ -0.00027,  -8.21136],
#        [ -0.0001 ,  -9.22856],
#        [ -0.00004, -10.2413 ],
#        [ -0.00004, -10.18878]], dtype=float32)

# %%
probs =  np.exp(log_preds[:,1])
probs
# Out:
# array([0.00001, 0.00027, 0.0001 , ..., 0.9992 , 0.99998, 0.99944], dtype=float32)

# %%
preds  = np.argmax(log_preds,1)
preds[0:5]
# Out:
# array([0, 0, 0, 0, 0])

# %%
learn.summary()
# Out:
# OrderedDict([('Conv2d-1',
#               OrderedDict([('input_shape', [-1, 3, 224, 224]),
#                            ('output_shape', [-1, 64, 112, 112]),
#                            ('trainable', False),
#                            ('nb_params', 9408)])),
#              ('BatchNorm2d-2',
#               OrderedDict([('input_shape', [-1, 64, 112, 112]),
#                            ('output_shape', [-1, 64, 112, 112]),
#                            ('trainable', False),
#                            ('nb_params', 128)])),
#              ('ReLU-3',
#               OrderedDict([('input_shape', [-1, 64, 112, 112]),
#                            ('output_shape', [-1, 64, 112, 112]),
#                            ('nb_params', 0)])),
#              ('MaxPool2d-4',
#               OrderedDict([('input_shape', [-1, 64, 112, 112]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('nb_params', 0)])),
#              ('Conv2d-5',
# ...

# %% [markdown]
# # <div style="direction:rtl ;font-family: B Nazanin ;font-size:27px; line-height: 170%; text-align: right">بررسی نتایج مدل</div>

# %%
def rand_by_mask(mask): 
    return np.random.choice(np.where(mask)[0], 4, replace=False)
def rand_by_correct(is_correct): 
    return rand_by_mask((preds == data.val_y)==is_correct)

# %%
def plots(ims, figsize=(12,6), rows=1, titles=None):
    f = plt.figure(figsize=figsize)
    for i in range(len(ims)):
        sp = f.add_subplot(rows, len(ims)//rows, i+1)
        sp.axis('Off')
        if titles is not None: sp.set_title(titles[i], fontsize=16)
        plt.imshow(ims[i])

# %%
def load_img_id(ds, idx): 
    return np.array(PIL.Image.open(PATH+ds.fnames[idx]))

def plot_val_with_title(idxs, title):
    imgs = [load_img_id(data.val_ds,x) for x in idxs]
    title_probs = [probs[x] for x in idxs]
    print(title)
    return plots(imgs, rows=1, titles=title_probs, figsize=(16,8))

# %%
plot_val_with_title(rand_by_correct(True), "Correctly classified")
# Out:
# Correctly classified

# %%
plot_val_with_title(rand_by_correct(False), "Incorrectly classified")
# Out:
# Incorrectly classified

# %%
def most_by_mask(mask, mult):
    idxs = np.where(mask)[0]
    return idxs[np.argsort(mult * probs[idxs])[:4]]

def most_by_correct(y, is_correct): 
    mult = -1 if (y==1)==is_correct else 1
    return most_by_mask(((preds == data.val_y)==is_correct) & (data.val_y == y), mult)

# %%
plot_val_with_title(most_by_correct(0, True), "Most correct cats")
# Out:
# Most correct cats

# %%
plot_val_with_title(most_by_correct(1, True), "Most correct dogs")
# Out:
# Most correct dogs

# %%
plot_val_with_title(most_by_correct(0, False), "Most incorrect cats")
# Out:
# Most incorrect cats

# %%
plot_val_with_title(most_by_correct(1, False), "Most incorrect dogs")
# Out:
# Most incorrect dogs

# %%
most_uncertain = np.argsort(np.abs(probs -0.5))[:4]
plot_val_with_title(most_uncertain, "Most uncertain predictions")
# Out:
# Most uncertain predictions

# %%
learn.save('resnet34_224')

# %%
learn.load('resnet34_224')

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(data.val_y,preds)

# %%
plot_confusion_matrix(cm,data.classes)
# Out:
# [[993   7]
#  [ 14 970]]

# %% [markdown]
# # <div style="direction:rtl ;font-family: B Nazanin ;font-size:34px; line-height: 170%; text-align: right">انتخاب نرخ یادگیری بهینه </div>

# %% [markdown]
#  ![title](images/lr.jpeg)

# %% [markdown]
# <div style="direction:rtl ;font-family: B Nazanin ;font-size:23px; line-height: 170%; text-align: right">
#
# راه حلی که در کتابخانه fastaiبرای پیدا کردن نرخ یادگیری بهینه پیاده سازی شده است. این راه حل بر اساس مقاله Leslie Smith موسوم به Cyclical Learning Rates for training Neural Networks پیاده سازی شده است. ایده پشت این رویکرد را می توانیم به صورت زیر خلاصه کنیم:
#
#
# </div>
#
# <div style="direction:rtl ;font-family: B Nazanin ;font-size:23px; line-height: 170%; text-align: right">
#
#
# <ol>
# <li>
# ابتدا برای دسته اول داده با یک نرخ یادگیری کوچک شروع و مقدار زیان مجموعه اعتبارسنجی را محاسبه کنیم.
#
# </li>
#
# <li>
# سپس به صورت آرام آرام نرخ یادگیری را برای دسته های بعدی افزایش دهیم و برای آن هم در هر بار مقدار زیان را محاسبه کنیم.
#
# </li>
#
# <li>
# زمانی که با روند خیلی صعودی زیان در حال افزایش پیدا خیلی زیاد بود فرآیند آموزش را متوقف می کنیم.
#
# </li>
#
# <li>
# بالاترین نرخ یادگیری که کماکان با آن زیان به صورت واضحی در حال  پیدا کردن است (نقطه ای که بیشترین کاهش در زیان را دارد نه نقطه ای که کمترین مقدار زیان برای آن ثبت شده است) را به عنوان نرخ یادگیری انتخاب می کنیم.
# </li>
#
#
# </ol>
# </div>

# %% [markdown]
#  ![title](images/lrfinder.png)

# %%
learn = ConvLearner.pretrained(arch, data)
learn.lr_find()
# Out:
# ...
#  84%|████████▍ | 304/360 [00:42<00:07,  7.19it/s, loss=0.386]

# %%
learn.sched.plot()

# %%
learn.sched.plot_loss()

# %% [markdown]
# <div style="direction:rtl ;font-family: B Nazanin ;font-size:23px; line-height: 170%; text-align: right">
# افزایش نرخ یادگیری هم می تواند به صورت نمایی باشد و هم به صورت خطی
#
#
# </div>

# %%
learn.sched.plot_lr()

# %% [markdown]
# # <div style="direction:rtl ;font-family: B Nazanin ;font-size:44px; line-height: 170%; text-align: right"> راهکارهای بهبود مدل </div>
#
# # <div style="direction:rtl ;font-family: B Nazanin ;font-size:27px; line-height: 170%; text-align: right"> استفاده از مدل های پیچیده تر </div>

# %%
arch = resnet50
size = 224
tfms = tfms_from_model(arch, size,
                      aug_tfms = transforms_side_on,
                      max_zoom = 1.1)

# %% [markdown]
# # <div style="direction:rtl ;font-family: B Nazanin ;font-size:27px; line-height: 170%; text-align: right"> استفاده از داده افزایی  </div>

# %%
tfms = tfms_from_model(arch, size,
                      aug_tfms = transforms_top_down,
                      max_zoom = 1.1)
def get_augs():
    data = ImageClassifierData.from_paths(PATH,bs =1,
                                         tfms = tfms)
    x,_  = next(iter(data.aug_dl))
    return data.trn_ds.denorm(x)[0]

# %%
ims = np.stack([get_augs() for i in range(9)])
plots(ims,rows=3)

# %%
arch = resnet50
tfms = tfms_from_model(arch,size,
                       aug_tfms=transforms_side_on,
                      max_zoom = 1.1 )

# %%
data = ImageClassifierData.from_paths(PATH, tfms=tfms)
learn = ConvLearner.pretrained(arch,data,
                               precompute=False)
learn.fit(0.01,3)
# Out:
# ...
# epoch      trn_loss   val_loss   accuracy
#     0      0.040615   0.023678   0.991935
#     1      0.030329   0.024566   0.991431
#     2      0.030934   0.023657   0.991431
# [array([0.02366]), 0.9914314516129032]

# %% [markdown]
# # <div style="direction:rtl ;font-family: B Nazanin ;font-size:27px; line-height: 170%; text-align: right">  تبرید نرخ یادگیری </div>
# <div style="direction:rtl ;font-family: B Nazanin ;font-size:27px; line-height: 170%; text-align: right">
# هر چه که به کمینه تابع زیان نزدیک می شویم نرخ یادگیری کوچکتری را انتخاب می کنیم تا گام های ما کوچک و کوچک تر شوند تا دقیقا به نقطه کمینه برسیم
#
# </div>

# %% [markdown]
#  ![title](images/lrannealing.PNG)

# %% [markdown]
# # <div style="direction:rtl ;font-family: B Nazanin ;font-size:27px; line-height: 170%; text-align: right"> گرادیان نزولی  تصادفی با ریستارت
#
# </div>
#
#
# <div style="direction:rtl ;font-family: B Nazanin ;font-size:27px; line-height: 170%; text-align: right"> وجود ممکن است در جایی از فضای وزن قرار بگیریم که با این وجود این که نقطه  ای که در آن هستیم یک نقطه بهینه محلی است و نتیجه نسبتا خوبی به ما می دهد ولی این نقطه بهینه خیلی نقطه پایداری نیست. یعنی تغییرات کوچک در وزنها منجر به تغییرات بزرگ در تابع زیان بشود و به همین خاطر اگر کمی دیتاست ما متفاوت باشد نتیجه کاملا متفاوت می گردد.
#
# </div>

# %% [markdown]
#  ![title](images/lrrestart.PNG)

# %% [markdown]
#  ![title](images/lrrestart2.PNG)

# %%
learn.fit(0.01,2, cycle_len = 1,cycle_mult=2)
# Out:
# ...
# epoch      trn_loss   val_loss   accuracy
#     0      0.031536   0.02287    0.991431
#     1      0.027753   0.023152   0.991935
#     2      0.022503   0.022924   0.991935
# [array([0.02292]), 0.9919354838709677]

# %%
learn.sched.plot_lr()

# %% [markdown]
# # <div style="direction:rtl ;font-family: B Nazanin ;font-size:27px; line-height: 170%; text-align: right">داده افزایی در زمان تست
#
# </div>
#
# <div style="direction:rtl ;font-family: B Nazanin ;font-size:27px; line-height: 170%; text-align: right">مدل ما عملکرد خوبی داشت ولی سوال پیش می آید که آیا میتوانیم عملکرد آن را حتی بهتر از این کنیم.
#
# </div>

# %%
log_preds,y = learn.TTA()
probs = np.mean(np.exp(log_preds),0)

# %%
accuracy_np(probs, y)
# Out:
# 0.9934475806451613

# %%
preds = np.argmax(probs, axis=1)
probs = probs[:,1]

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y, preds)

# %%
plot_confusion_matrix(cm, data.classes)
# Out:
# [[992   8]
#  [  5 979]]

# %%
trn_transform, val_transfrom = tfms_from_model(arch, size)
img = val_tfrms(Image.open('path_to'))
#learn.precompute=False
pred = learn.predict_array(img[None])
np.argmax(prd)

# %%
خلاصه

# %% [markdown]
# ![title](images/pretraind.PNG)
