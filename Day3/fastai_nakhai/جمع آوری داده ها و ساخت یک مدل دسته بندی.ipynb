# %%
# !pip install google_images_download
# Out:
# ...
# distributed 1.21.8 requires msgpack, which is not installed.
# You are using pip version 10.0.1, however version 18.0 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# !pip install selenium
# Out:
# ...
# distributed 1.21.8 requires msgpack, which is not installed.
# You are using pip version 10.0.1, however version 18.0 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
from google_images_download import google_images_download   #importing the library

response = google_images_download.googleimagesdownload()   #class instantiation

arguments = {"keywords":"leopard", "limit":220,
             "print_urls":False, "output_directory":"d://pics",
            "chromedriver": "D:\\app\\chromedriver.exe"}

response.download(arguments)  


arguments = {"keywords":"cheetah", "limit":220,
             "print_urls":False, "output_directory":"d://pics",
            "chromedriver": "D:\\app\\chromedriver.exe"}   

response.download(arguments)
# Out:
# Item no.: 1 --> Item name = leopard
# Evaluating...
# Getting you a lot of images. This may take a few moments...
# Reached end of Page.
# Starting Download...
# Completed Image ====> 1. 1200px-african_leopard%2c_panthera_pardus_pardus%2c_near_lake_panic%2c_kruger_national_park%2c_south_africa_%2819448654130%29.jpg
# Completed Image ====> 2. 220px-nagarhole_kabini_karnataka_india%2c_leopard_september_2013.jpg
# Completed Image ====> 3. 220px-panthera_pardus_close_up-2.jpg
# Completed Image ====> 4. %c2%a9benjamin_ackerman_scotia_female_exeter.jpg
# Completed Image ====> 5. sn-leopard.jpg
# Completed Image ====> 6. leop_billy.jpg
# Completed Image ====> 7. 1-kruger-park-leopard-in-tree-c-duplessis-590.jpg
# Completed Image ====> 8. main-qimg-3e8f7ddc15255d57908dfe39c3b9838e-c.jpg
# URLError on an image...trying next one... Error: <urlopen error [Errno 11002] getaddrinfo failed>
# ...

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.imports import *
from fastai.transforms import *
from fastai.model import *
from fastai.dataset import *
from fastai.conv_learner import *
from fastai.sgdr import * 
from fastai.plots import *

# %%
PATH = '/home/hamim/Desktop/nakhaee/ارائه/tempdiles/cheetahvsleopard/'

# %%
files = os.listdir(PATH + '/train/cheetah' )
files[0:2]
# Out:
# ['76. cheetah-cub-and-mother.jpg', '110. 11_11_15_cheetah.jpg']

# %%
img = plt.imread(PATH + '/train/cheetah/' +files[0])
plt.imshow(img)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(data.val_y,preds)


plot_confusion_matrix(cm, data.classes)
# Out:
# [[24  6]
#  [ 3 45]]

# %%
def rand_by_mask(mask): 
    return np.random.choice(np.where(mask)[0], 4, replace=False)
def rand_by_correct(is_correct): 
    return rand_by_mask((preds == data.val_y)==is_correct)

# %%
def plots(ims, figsize=(12,6), rows=1, titles=None):
    f = plt.figure(figsize=figsize)
    for i in range(len(ims)):
        sp = f.add_subplot(rows, len(ims)//rows, i+1)
        sp.axis('Off')
        if titles is not None: sp.set_title(titles[i], fontsize=16)
        plt.imshow(ims[i])

# %%
def load_img_id(ds, idx): 
    return np.array(PIL.Image.open(PATH+ds.fnames[idx]))

def plot_val_with_title(idxs, title):
    imgs = [load_img_id(data.val_ds,x) for x in idxs]
    title_probs = [probs[x] for x in idxs]
    print(title)
    return plots(imgs, rows=1, titles=title_probs, figsize=(16,8))
